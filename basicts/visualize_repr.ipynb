# %%
import numpy as np

from basicts.visualize_repr import visualize_repr, visualize_repr_decompose, visualize_similarities, visualize_mean_repr

result_file_dir_staeformer = "../checkpoints/STAEformer/PEMS08_100_12_12/base-0/test_repr.npz"
result_file_dir_staeformer_ssl = "../checkpoints/STAEformer_SSL/PEMS08_100_12_12/base-softclt/test_repr.npz"
result_file_dir_staeformer_ssl_sub = "../checkpoints/STAEformer_SSL/PEMS08_100_12_12/4104fb84fe25da918f362f0bbb78f260/test_repr.npz"
result_file_dir_staeformer_fs = "../checkpoints/STAEformer/PEMS08_100_12_12/5154b76a28d37361e94e849708bf6584/test_repr.npz"
result_file_dir_staeformer_fs_ssl = "../checkpoints/STAEformer_SSL/PEMS08_100_12_12/a4c78e002fd407ebeb86435d91606391/test_repr.npz"
result_file_dir_staeformer_ssl_g = "../checkpoints/STAEformer_SSL_G/PEMS08_100_12_12/da07ac4fc56a211b4813b242a4f732b4/test_repr.npz"
result_file_dir_staeformer_ssl_gr = "../checkpoints/STAEformer_SSL_G/PEMS08_100_12_12/f6a91530204e83a0cdb896d776b2814b/test_repr.npz"
result_file_dir_staeformer_ssl_gr_1 = "../checkpoints/STAEformer_SSL_G/PEMS08_100_12_12/051cc2a8d72388583249fb824db16230/test_repr.npz"
result_file_dir_staeformer_t_contrast = "../checkpoints/STAEformer_SSL/PEMS08_100_12_12/t_global_contrast_better/test_repr.npz"
result_file_dir_staeformer_t_contrast_5 = "../checkpoints/STAEformer_SSL/PEMS08_100_12_12/t_global_contrast_better_5/test_repr.npz"
result_file_dir_staeformer_base_contrast = "../checkpoints/STAEformer_SSL/PEMS08_100_12_12/base_contrast_sub/test_repr.npz"
result_file_dir_staeformer_c_contrast = "../checkpoints/STAEformer_SSL/PEMS08_100_12_12/c_contrast_32/test_repr.npz"
result_file_dir_staeformer_spatial_softclt = "../checkpoints/STAEformer_SSL/PEMS08_100_12_12/base-spatial-softclt/test_repr.npz"
temporal_softclt_pems08 = "/data3/hanzhi/BasicTS/checkpoints/STAEformer_SSL/PEMS08_100_12_12/base-temporal-softclt/test_repr.npz"
temporal_dist_softclt_pems08 = "/data3/hanzhi/BasicTS/checkpoints/STAEformer_SSL/PEMS08_100_12_12/base-temporal-dist-softclt/test_repr.npz"
temporal_ldist_softclt_pems08 = "/data3/hanzhi/BasicTS/checkpoints/STAEformer_SSL/PEMS08_100_12_12/base-temporal-ldist-softclt/test_repr.npz"



result_file_dir_staeformer_ssl_gr_2 = "../checkpoints/STAEformer_SSL_G/PEMS08_100_12_12/857c253edf44cae94e6ed29c7d723191/test_repr.npz"



result_file_dir_stid = "../checkpoints/STID/PEMS08_100_12_12/551c3b210568e20291fe6f0c26e17db2/test_repr.npz"
result_file_dir_stid_ssl = "../checkpoints/STID_SSL/PEMS08_100_12_12/bf6e6db18d46cdad27fb1769e31f3b3a/test_repr.npz"
result_file_dir_stid_fs = "../checkpoints/STID/PEMS08_100_12_12/59982790b7a7eb01e0aefd30a07f972f/test_repr.npz"
result_file_dir_stid_ssl_fs = "../checkpoints/STID_SSL/PEMS08_100_12_12/b8d5ddd429959ecb4fdd41d70ff9188c/test_repr.npz"

# DecomposeFormer的相关表示
result_file_dir_decompose_former_base = "/data3/hanzhi/BasicTS/checkpoints/DecomposeFormer_adv/PEMS08_100_12_12/31eef3d5fafc6584e73715599ad8d238/test_repr.npz"
result_file_dir_decompose_former_dual_loss = "/data3/hanzhi/BasicTS/checkpoints/DecomposeFormer_adv/PEMS08_100_12_12/f1ead17f437487f9b4ea4cb975549a39/test_repr.npz"
result_file_dir_decompose_former_tts = "/data3/hanzhi/BasicTS/checkpoints/DecomposeFormer_TTS/PEMS08_100_12_12/d7fde011127742d7ea670292ecf8abd9/test_repr.npz"

result_file_dir_decompose_former_ssl = "/data3/hanzhi/BasicTS/checkpoints/DecomposeFormer_TTS_SSL/PEMS08_100_12_12/da2a29003a00a13216fe853df172d9eb/test_repr.npz"
result_file_dir_decompose_former_s_ssl = "/data3/hanzhi/BasicTS/checkpoints/DecomposeFormer_TTS_S_SSL/PEMS08_100_12_12/44be1e0e1eeb75f4c29602f74fc3675a/test_repr.npz"
#visualize_repr([result_file_dir_staeformer, result_file_dir_staeformer_ssl,result_file_dir_staeformer_fs,result_file_dir_staeformer_fs_ssl], [0 for i in range(4)]+[100 for i in range(4)], [162, 169, 108, 153])
window_ids = [0 for i in range(5)]+[100 for i in range(5)]
sensor_ids = [0, 162, 169, 108, 153] * 2
#visualize_repr([temporal_softclt_pems08, result_file_dir_staeformer, result_file_dir_staeformer_t_contrast_5,result_file_dir_staeformer_c_contrast, result_file_dir_staeformer_base_contrast, result_file_dir_staeformer_ssl, result_file_dir_staeformer_spatial_softclt, ], 0, 169)
#visualize_repr([temporal_softclt_pems08, result_file_dir_staeformer, result_file_dir_staeformer_t_contrast_5,result_file_dir_staeformer_c_contrast, result_file_dir_staeformer_base_contrast, result_file_dir_staeformer_ssl, result_file_dir_staeformer_spatial_softclt], 0, 153)
visualize_repr([result_file_dir_staeformer, result_file_dir_staeformer_base_contrast, result_file_dir_staeformer_ssl, result_file_dir_staeformer_spatial_softclt, temporal_softclt_pems08, temporal_dist_softclt_pems08, temporal_ldist_softclt_pems08], 0, 169, names=["base", "staeformer-base-contrast", "staeformer-softclt", "staeformer-spatial-softclt", "staeformer-temporal-softclt", "staeformer-temporal-dist-softclt", "staeformer-temporal-ldist-softclt"])
visualize_mean_repr([result_file_dir_staeformer, result_file_dir_staeformer_ssl, temporal_softclt_pems08, temporal_dist_softclt_pems08, temporal_ldist_softclt_pems08], 0)

#visualize_repr_decompose(result_file_dir_staeformer_ssl_gr, window_ids, sensor_ids)
visualize_similarities([result_file_dir_staeformer, result_file_dir_staeformer_base_contrast, result_file_dir_staeformer_ssl, result_file_dir_staeformer_spatial_softclt, temporal_softclt_pems08, temporal_dist_softclt_pems08, temporal_ldist_softclt_pems08], names=["base", "staeformer-base-contrast", "staeformer-softclt", "staeformer-spatial-softclt", "staeformer-temporal-softclt", "staeformer-temporal-dist-softclt", "staeformer-temporal-ldist-softclt"])
# Out:
# ...
# 100%|██████████| 3548/3548 [00:23<00:00, 149.41it/s]
