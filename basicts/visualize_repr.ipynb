# %%
import numpy as np

from basicts.visualize_repr import visualize_repr

result_file_dir = "../checkpoints/GraphWaveNet/PEMS04_100_12_12/580cf696b2ed1716596aa5ee4c96ba10/test_repr.npz"

visualize_repr(result_file_dir, 0, 0)
visualize_repr(result_file_dir, 150, 0)
